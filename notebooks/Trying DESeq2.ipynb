# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/64_genes.csv').drop(columns=['Unnamed: 0'])
df.head()
# Out:
#    ENSG00000134184.11  ENSG00000117650.11  ENSG00000012048.18  \
# 0              2135.0               804.0              1149.0
# 1                 9.0              2031.0              3094.0
# 2                 5.0                 4.0               698.0
# 3                 0.0              1313.0               625.0
# 4              3931.0               172.0               330.0
#
#    ENSG00000137804.11  ENSG00000197170.8  ENSG00000123975.4  \
# 0              2065.0             6867.0             1162.0
# 1              5309.0             8698.0             2275.0
# 2                90.0             3789.0               88.0
# 3              1853.0            11700.0             2411.0
# 4               293.0             1319.0             2277.0
#
#    ENSG00000131747.13  ENSG00000136997.13  ENSG00000175063.15  \
# 0              4794.0              4262.0               674.0
# 1             25236.0              6687.0              3088.0
# ...

# %%
genes = df.drop(columns=['tumor_stage'])
genes = genes.T

# %%
genes['id'] = genes.index

# %%
sample_df = pd.DataFrame({'samplename': genes.columns}) \
        .query('samplename != "id"')
sample_df.index = sample_df.samplename
sample_df
# Out:
#            samplename
# samplename
# 0                   0
# 1                   1
# 2                   2
# 3                   3
# 4                   4
# ...               ...
# 1135             1135
# 1136             1136
# 1137             1137
# 1138             1138
# 1139             1139
#
# [1140 rows x 1 columns]

# %%
from diffexpr.py_deseq import py_DESeq2

dds = py_DESeq2(count_matrix = genes,
               design_matrix = sample_df,
               design_formula = '~ sample',
               gene_column = 'id') # <- telling DESeq2 this should be the gene ID column
    
dds.run_deseq() 
dds.get_deseq_result()
res = dds.deseq_result 
res.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-c9e2cafd6a6d> in <module>
#       4                design_matrix = sample_df,
#       5                design_formula = '~ sample',
# ----> 6                gene_column = 'id') # <- telling DESeq2 this should be the gene ID column
#       7
#       8 dds.run_deseq()
#
# ~/workspace/tumor_staging_classification/notebooks/diffexpr/py_deseq.py in __init__(self, count_matrix, design_matrix, design_formula, gene_column)
#      48         self.gene_id = count_matrix[self.gene_column]
#      49         self.samplenames = count_matrix.columns[count_matrix.columns != self.gene_column]
# ---> 50         self.count_matrix = pandas2ri.py2ri(count_matrix.set_index(self.gene_column))
#      51         self.design_matrix = pandas2ri.py2ri(design_matrix)
#      52         self.design_formula = Formula(design_formula)
#
# ...
